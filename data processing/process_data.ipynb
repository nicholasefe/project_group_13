# %%
import pandas as pd
df = pd.read_csv('https://query.data.world/s/vqvuxbengifvu22nhkloxxowurownr?dws=00000')

# %%
len(df.columns)
# Out:
# 15

# %%
df
# Out:
#        Provider_ID                           Hospital_Name  \
# 0            10001        SOUTHEAST ALABAMA MEDICAL CENTER
# 1            10001        SOUTHEAST ALABAMA MEDICAL CENTER
# 2            10001        SOUTHEAST ALABAMA MEDICAL CENTER
# 3            10001        SOUTHEAST ALABAMA MEDICAL CENTER
# 4            10001        SOUTHEAST ALABAMA MEDICAL CENTER
# ...            ...                                     ...
# 19463       480002  GOV JUAN F LUIS HOSPITAL & MEDICAL CTR
# 19464       480002  GOV JUAN F LUIS HOSPITAL & MEDICAL CTR
# 19465       480002  GOV JUAN F LUIS HOSPITAL & MEDICAL CTR
# 19466       650001        GUAM MEMORIAL HOSPITAL AUTHORITY
# 19467       650001        GUAM MEMORIAL HOSPITAL AUTHORITY
#
#                                      Address      City State  ZIP_Code  \
# 0                     1108 ROSS CLARK CIRCLE    DOTHAN    AL     36301
# 1                     1108 ROSS CLARK CIRCLE    DOTHAN    AL     36301
# ...

# %%
df.describe()
# Out:
#          Provider_ID      ZIP_Code           Days  Predicted_Cases  \
# count   19468.000000  19468.000000   19468.000000     19468.000000
# mean   261678.350473  52009.857715   16422.326433         8.781783
# std    158946.620886  28159.506085   37573.388948        22.434670
# min     10001.000000    674.000000       1.000000        -1.000000
# 25%    110187.000000  29927.000000     104.000000         0.497750
# 50%    250096.500000  49068.000000    1653.500000         1.889500
# 75%    390119.000000  76401.000000   12394.500000         6.024500
# max    670089.000000  99901.000000  692944.000000       546.511000
#
#        Observed_Cases           SIR
# count    19468.000000  19468.000000
# mean         7.865112      0.167288
# std         22.719545      1.071421
# min         -1.000000     -1.000000
# 25%          0.000000     -1.000000
# 50%          1.000000      0.237000
# 75%          5.000000      0.884000
# max        553.000000     10.041000

# %%
df.dtypes
# Out:
# Provider_ID             int64
# Hospital_Name          object
# Address                object
# City                   object
# State                  object
# ZIP_Code                int64
# County_Name            object
# Hospital_Type          object
# Hospital_Ownership     object
# Emergency_Services       bool
# Disease_Name           object
# Days                  float64
# Predicted_Cases       float64
# Observed_Cases          int64
# SIR                   float64
# dtype: object

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 19468 entries, 0 to 19467
# Data columns (total 15 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   Provider_ID         19468 non-null  int64
#  1   Hospital_Name       19468 non-null  object
#  2   Address             19468 non-null  object
#  3   City                19468 non-null  object
#  4   State               19468 non-null  object
#  5   ZIP_Code            19468 non-null  int64
#  6   County_Name         19448 non-null  object
#  7   Hospital_Type       19468 non-null  object
#  8   Hospital_Ownership  19468 non-null  object
#  9   Emergency_Services  19468 non-null  bool
#  10  Disease_Name        19468 non-null  object
#  11  Days                19468 non-null  float64
#  12  Predicted_Cases     19468 non-null  float64
#  13  Observed_Cases      19468 non-null  int64
#  14  SIR                 19468 non-null  float64
# ...
